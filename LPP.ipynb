# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop_price.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df['Prices'] = df['Price_euros']*(90.14)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros       Prices
# 0      1339.69  120759.6566
# 1       898.94   81030.4516
# 2       575.00   51830.5000
# 3      2537.45  228725.7430
# 4      1803.60  162576.5040

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS   1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS   1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS   1.37
#
#    Price_euros       Prices
# 0      1339.69  120759.6566
# 1       898.94   81030.4516
# 2       575.00   51830.5000
# 3      2537.45  228725.7430
# 4      1803.60  162576.5040

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   int32
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   float32
#  12  Price_euros       1303 non-null   float64
#  13  Prices            1303 non-null   float64
# dtypes: float32(1), float64(3), int32(1), int64(1), object(8)
# memory usage: 132.5+ KB

# %%
import seaborn as sn

# %%
sn.distplot(df['Prices'])
# Out:
# C:\Users\ROSHNI\AppData\Local\Temp\ipykernel_11656\85142551.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['Prices'])
# <Axes: xlabel='Prices', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sn.barplot(x=df['Company'],y=df['Prices'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sn.barplot(x=df['TypeName'],y=df['Prices'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sn.distplot(df['Inches'])
# Out:
# C:\Users\ROSHNI\AppData\Local\Temp\ipykernel_11656\3563125449.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sn.scatterplot(x=df['Inches'],y=df['Prices'])
# Out:
# <Axes: xlabel='Inches', ylabel='Prices'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head(6)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
# 5          6    Acer     Aspire 3   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
# 5                            1366x768     AMD A9-Series 9420 3GHz    4
#
#                 Memory                           Gpu       OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640       macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000       macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620       No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455       macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650       macOS    1.37
# 5            500GB HDD                 AMD Radeon R5  Windows 10    2.10
#
#    Price_euros       Prices  Touchscreen
# 0      1339.69  120759.6566            0
# 1       898.94   81030.4516            0
# 2       575.00   51830.5000            0
# 3      2537.45  228725.7430            0
# 4      1803.60  162576.5040            0
# 5       400.00   36056.0000            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sn.barplot(x=df['Touchscreen'], y=df['Prices'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Prices'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros       Prices  Touchscreen  IPS
# 0      1339.69  120759.6566            0    1
# 1       898.94   81030.4516            0    0
# 2       575.00   51830.5000            0    0
# 3      2537.45  228725.7430            0    1
# 4      1803.60  162576.5040            0    1

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sn.barplot(x=df['IPS'], y=df['Prices'])
# Out:
# <Axes: xlabel='IPS', ylabel='Prices'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
#to create two columns on the resolution
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#       laptop_ID Company         Product  TypeName  Inches  \
# 1068       1083    Dell    Alienware 15    Gaming    15.6
# 878         889    Dell     Vostro 5568  Notebook    15.6
# 1046       1060      HP  EliteBook 1040  Notebook    14.0
# 917         931     MSI      GE72VR 6RF    Gaming    17.3
# 666         674    Dell   Latitude 3580  Notebook    15.6
#
#            ScreenResolution                          Cpu  Ram  \
# 1068  4K Ultra HD 3840x2160  Intel Core i7 6700HQ 2.6GHz   16
# 878       Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    4
# 1046      Full HD 1920x1080   Intel Core i5 6200U 2.3GHz    8
# 917       Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz   16
# 666       Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    8
#
#                     Memory                         Gpu       OpSys  Weight  \
# 1068  256GB SSD +  1TB HDD     Nvidia GeForce GTX 970M  Windows 10    3.21
# 878   128GB SSD +  1TB HDD        Nvidia GeForce 940MX  Windows 10    2.18
# 1046             256GB SSD       Intel HD Graphics 520   Windows 7    1.43
# 917   256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10    2.70
# 666                1TB HDD       Intel HD Graphics 620  Windows 10    2.06
#
#       Price_euros     Prices  Touchscreen  IPS             X_res Y_res
# 1068       1329.0  119796.06            0    0  4K Ultra HD 3840  2160
# 878         912.5   82252.75            0    0      Full HD 1920  1080
# 1046       1469.0  132415.66            0    0      Full HD 1920  1080
# 917        1599.0  144133.86            0    0      Full HD 1920  1080
# 666         955.0   86083.70            0    0      Full HD 1920  1080

# %%
#we will use regular expression to get integers only(digits)
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.sample(5)
# Out:
#       laptop_ID  Company                                    Product  \
# 1191       1209  Samsung                            Chromebook Plus
# 176         180     Acer                             Aspire A315-51
# 578         585      MSI                               GT73VR Titan
# 534         541     Asus                                  ROG Strix
# 291         296     Asus  FX753VD-GC071T (i7-7700HQ/8GB/1TB/GeForce
#
#                 TypeName  Inches                 ScreenResolution  \
# 1191  2 in 1 Convertible    12.3  IPS Panel Touchscreen 2400x1600
# 176             Notebook    15.6                         1366x768
# 578               Gaming    17.3                Full HD 1920x1080
# 534               Gaming    15.6      IPS Panel Full HD 1920x1080
# 291               Gaming    17.3                Full HD 1920x1080
#
#                                 Cpu  Ram                Memory  \
# 1191  Samsung Cortex A72&A53 2.0GHz    4    32GB Flash Storage
# 176        Intel Core i3 6006U 2GHz    4             128GB SSD
# 578     Intel Core i7 7820HK 2.9GHz   16  512GB SSD +  1TB HDD
# 534     Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 291     Intel Core i7 7700HQ 2.8GHz    8               1TB HDD
#
#                           Gpu       OpSys  Weight  Price_euros     Prices  \
# 1191        ARM Mali T860 MP4   Chrome OS    1.15        659.0   59402.26
# 176     Intel HD Graphics 520  Windows 10    2.10        449.0   40472.86
# 578   Nvidia GeForce GTX 1070  Windows 10    4.14       2729.0  245992.06
# 534   Nvidia GeForce GTX 1060  Windows 10    2.30       1649.0  148640.86
# 291   Nvidia GeForce GTX 1050  Windows 10    3.00       1187.0  106996.18
#
#       Touchscreen  IPS X_res Y_res
# 1191            1    1  2400  1600
# 176             0    0  1366   768
# 578             0    0  1920  1080
# 534             0    1  1920  1080
# 291             0    0  1920  1080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   int32
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   float32
#  12  Price_euros       1303 non-null   float64
#  13  Prices            1303 non-null   float64
#  14  Touchscreen       1303 non-null   int64
#  15  IPS               1303 non-null   int64
#  16  X_res             1303 non-null   object
#  17  Y_res             1303 non-null   object
# dtypes: float32(1), float64(3), int32(1), int64(3), object(10)
# memory usage: 173.2+ KB

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int32
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float32
# Price_euros         float64
# Prices              float64
# Touchscreen           int64
# IPS                   int64
# X_res                 int32
# Y_res                 int32
# dtype: object

# %%
num_df = df.select_dtypes(include=[np.number])
num_df.corr()['Prices']
# Out:
# laptop_ID      0.067830
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price_euros    1.000000
# Prices         1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Prices, dtype: float64

# %%
# we create a new ccolumn determining the pixels per inches(PPI) so as to decrease the multicolinearity 
df['PPI'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.sample(5)
# Out:
#      laptop_ID Company                                    Product  TypeName  \
# 873        884  Lenovo                                Thinkpad 13  Notebook
# 313        318    Acer   ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook
# 477        484  Lenovo                              Thinkpad T470  Notebook
# 40          41    Asus  X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)  Notebook
# 248        253      HP                                ProBook 430  Notebook
#
#      Inches             ScreenResolution                         Cpu  Ram  \
# 873    13.3  IPS Panel Full HD 1920x1080  Intel Core i3 7100U 2.4GHz    4
# 313    15.6            Full HD 1920x1080   AMD A8-Series 7410 2.2GHz    8
# 477    14.0            Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 40     15.6            Full HD 1920x1080    Intel Core i3 6006U 2GHz    4
# 248    13.3  IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz    4
#
#         Memory                     Gpu       OpSys  Weight  Price_euros  \
# 873  180GB SSD   Intel HD Graphics 620  Windows 10    1.44        735.0
# 313  256GB SSD           AMD Radeon R5  Windows 10    2.23        469.0
# 477  180GB SSD   Intel HD Graphics 620  Windows 10    1.70       1364.0
# 40     1TB HDD   Intel HD Graphics 620       Linux    2.00        389.0
# 248  500GB HDD  Intel UHD Graphics 620  Windows 10    1.49        675.0
#
#         Prices  Touchscreen  IPS  X_res  Y_res         PPI
# 873   66252.90            0    1   1920   1080  165.632118
# 313   42275.66            0    0   1920   1080  141.211998
# 477  122950.96            0    0   1920   1080  157.350512
# 40    35064.46            0    0   1920   1080  141.211998
# 248   60844.50            0    1   1920   1080  165.632118

# %%
df.drop(columns = ['ScreenResolution','Inches','X_res','Y_res','Price_euros'], inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName                         Cpu  Ram  \
# 0          1   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1          2   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2          3      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3          4   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4          5   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#         Prices  Touchscreen  IPS         PPI
# 0  120759.6566            0    1  226.983005
# 1   81030.4516            0    0  127.677940
# 2   51830.5000            0    0  141.211998
# 3  228725.7430            0    1  220.534624
# 4  162576.5040            0    1  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName                         Cpu  Ram  \
# 0          1   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1          2   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2          3      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3          4   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4          5   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#         Prices  Touchscreen  IPS         PPI       Cpu_Name
# 0  120759.6566            0    1  226.983005  Intel Core i5
# 1   81030.4516            0    0  127.677940  Intel Core i5
# 2   51830.5000            0    0  141.211998  Intel Core i5
# 3  228725.7430            0    1  220.534624  Intel Core i7
# 4  162576.5040            0    1  226.983005  Intel Core i5

# %%
def fetch_text(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_Brand'] = df['Cpu_Name'].apply(fetch_text)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName                         Cpu  Ram  \
# 0          1   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1          2   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2          3      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3          4   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4          5   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#         Prices  Touchscreen  IPS         PPI       Cpu_Name      Cpu_Brand
# 0  120759.6566            0    1  226.983005  Intel Core i5  Intel Core i5
# 1   81030.4516            0    0  127.677940  Intel Core i5  Intel Core i5
# 2   51830.5000            0    0  141.211998  Intel Core i5  Intel Core i5
# 3  228725.7430            0    1  220.534624  Intel Core i7  Intel Core i7
# 4  162576.5040            0    1  226.983005  Intel Core i5  Intel Core i5

# %%
df['Cpu_Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu_Brand'>

# %%
sn.barplot(x=df['Cpu_Brand'],y=df['Prices'])
plt.xticks(rotation = 'vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.drop(columns=['Cpu','Cpu_Name'], inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram               Memory  \
# 0          1   Apple  MacBook Pro  Ultrabook    8            128GB SSD
# 1          2   Apple  Macbook Air  Ultrabook    8  128GB Flash Storage
# 2          3      HP       250 G6   Notebook    8            256GB SSD
# 3          4   Apple  MacBook Pro  Ultrabook   16            512GB SSD
# 4          5   Apple  MacBook Pro  Ultrabook    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sn.barplot(x=df['Ram'],y=df['Prices'])
# Out:
# <Axes: xlabel='Ram', ylabel='Prices'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df1 = pd.read_csv('laptop_price.csv',encoding='latin-1')

# %%
df['Memory'] = df1['Memory']

# %%
# Step 1: Convert to string and remove '.0'
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# Step 2: Remove 'GB' and replace 'TB' with '000'
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Step 3: Split into two parts
new = df["Memory"].str.split("+", n=1, expand=True)

# Step 4: Clean and separate first and second parts
df["first"] = new[0].str.strip()
df["second"] = new[1].str.strip() if new.shape[1] > 1 else "0"

# Step 5: Identify storage types in the first part
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 6: Remove non-digit characters from the first part
df['first'] = df['first'].str.extract(r'(\d+)')[0]

# Step 7: Handle missing values in the second part
df["second"].fillna("0", inplace=True)

# Step 8: Identify storage types in the second part
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 9: Remove non-digit characters from the second part
df['second'] = df['second'].str.extract(r'(\d+)')[0]

# Step 10: Replace empty strings with NaN and fill NaN with zero
df['first'] = df['first'].replace('', np.nan).fillna(0).astype(int)
df['second'] = df['second'].replace('', np.nan).fillna(0).astype(int)

# Step 11: Calculate total storage for each type
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# Step 12: Drop intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)

# Step 13: Convert final storage columns to float
df['HDD'] = df['HDD'].astype(float)
df['SSD'] = df['SSD'].astype(float)
df['Hybrid'] = df['Hybrid'].astype(float)
df['Flash_Storage'] = df['Flash_Storage'].astype(float)

print(df.head())
# Out:
#    laptop_ID Company      Product   TypeName  Ram             Memory  \
# 0          1   Apple  MacBook Pro  Ultrabook    8            128 SSD
# 1          2   Apple  Macbook Air  Ultrabook    8  128 Flash Storage
# 2          3      HP       250 G6   Notebook    8            256 SSD
# 3          4   Apple  MacBook Pro  Ultrabook   16            512 SSD
# 4          5   Apple  MacBook Pro  Ultrabook    8            256 SSD
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand  HDD    SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5  0.0  128.0     0.0            0.0
# 1  127.677940  Intel Core i5  0.0    0.0     0.0          128.0
# 2  141.211998  Intel Core i5  0.0  256.0     0.0            0.0
# 3  220.534624  Intel Core i7  0.0  512.0     0.0            0.0
# 4  226.983005  Intel Core i5  0.0  256.0     0.0            0.0

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram             Memory  \
# 0          1   Apple  MacBook Pro  Ultrabook    8            128 SSD
# 1          2   Apple  Macbook Air  Ultrabook    8  128 Flash Storage
# 2          3      HP       250 G6   Notebook    8            256 SSD
# 3          4   Apple  MacBook Pro  Ultrabook   16            512 SSD
# 4          5   Apple  MacBook Pro  Ultrabook    8            256 SSD
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand  HDD    SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5  0.0  128.0     0.0            0.0
# 1  127.677940  Intel Core i5  0.0    0.0     0.0          128.0
# 2  141.211998  Intel Core i5  0.0  256.0     0.0            0.0
# 3  220.534624  Intel Core i7  0.0  512.0     0.0            0.0
# 4  226.983005  Intel Core i5  0.0  256.0     0.0            0.0

# %%
df['HDD'] = df['HDD'].astype(int)
df['SSD'] = df['SSD'].astype(int)
df['Hybrid'] = df['Hybrid'].astype(int)
df['Flash_Storage'] = df['Flash_Storage'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   laptop_ID      1303 non-null   int64
#  1   Company        1303 non-null   object
#  2   Product        1303 non-null   object
#  3   TypeName       1303 non-null   object
#  4   Ram            1303 non-null   int32
#  5   Memory         1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   float32
#  9   Prices         1303 non-null   float64
#  10  Touchscreen    1303 non-null   int64
#  11  IPS            1303 non-null   int64
#  12  PPI            1303 non-null   float64
#  13  Cpu_Brand      1303 non-null   object
#  14  HDD            1303 non-null   int32
#  15  SSD            1303 non-null   int32
#  16  Hybrid         1303 non-null   int32
#  17  Flash_Storage  1303 non-null   int32
# dtypes: float32(1), float64(2), int32(5), int64(3), object(7)
# memory usage: 152.8+ KB

# %%
num_df = df.select_dtypes(include=[np.number])
num_df.corr()['Prices']
# Out:
# laptop_ID        0.067830
# Ram              0.743007
# Weight           0.210370
# Prices           1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Prices, dtype: float64

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram             Memory  \
# 0          1   Apple  MacBook Pro  Ultrabook    8            128 SSD
# 1          2   Apple  Macbook Air  Ultrabook    8  128 Flash Storage
# 2          3      HP       250 G6   Notebook    8            256 SSD
# 3          4   Apple  MacBook Pro  Ultrabook   16            512 SSD
# 4          5   Apple  MacBook Pro  Ultrabook    8            256 SSD
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# 1  127.677940  Intel Core i5    0    0       0            128
# 2  141.211998  Intel Core i5    0  256       0              0
# 3  220.534624  Intel Core i7    0  512       0              0
# 4  226.983005  Intel Core i5    0  256       0              0

# %%
df.drop(columns=['Hybrid','Flash_Storage','Memory'],inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram  \
# 0          1   Apple  MacBook Pro  Ultrabook    8
# 1          2   Apple  Macbook Air  Ultrabook    8
# 2          3      HP       250 G6   Notebook    8
# 3          4   Apple  MacBook Pro  Ultrabook   16
# 4          5   Apple  MacBook Pro  Ultrabook    8
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand  HDD  SSD
# 0  226.983005  Intel Core i5    0  128
# 1  127.677940  Intel Core i5    0    0
# 2  141.211998  Intel Core i5    0  256
# 3  220.534624  Intel Core i7    0  512
# 4  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_Brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram  \
# 0          1   Apple  MacBook Pro  Ultrabook    8
# 1          2   Apple  Macbook Air  Ultrabook    8
# 2          3      HP       250 G6   Notebook    8
# 3          4   Apple  MacBook Pro  Ultrabook   16
# 4          5   Apple  MacBook Pro  Ultrabook    8
#
#                             Gpu  OpSys  Weight       Prices  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120759.6566            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   81030.4516            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51830.5000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228725.7430            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162576.5040            0    1
#
#           PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['Gpu_Brand'].value_counts()
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
sn.barplot(x=df['Gpu_Brand'],y=df['Prices'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram  OpSys  Weight       Prices  \
# 0          1   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  120759.6566
# 1          2   Apple  Macbook Air  Ultrabook    8  macOS    1.34   81030.4516
# 2          3      HP       250 G6   Notebook    8  No OS    1.86   51830.5000
# 3          4   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  228725.7430
# 4          5   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  162576.5040
#
#    Touchscreen  IPS         PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel
# 2            0    0  141.211998  Intel Core i5    0  256     Intel
# 3            0    1  220.534624  Intel Core i7    0  512       AMD
# 4            0    1  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sn.barplot(x=df['OpSys'],y=df['Prices'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Ram  OpSys  Weight       Prices  \
# 0          1   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  120759.6566
# 1          2   Apple  Macbook Air  Ultrabook    8  macOS    1.34   81030.4516
# 2          3      HP       250 G6   Notebook    8  No OS    1.86   51830.5000
# 3          4   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  228725.7430
# 4          5   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  162576.5040
#
#    Touchscreen  IPS         PPI      Cpu_Brand  HDD  SSD Gpu_Brand  \
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel
# 2            0    0  141.211998  Intel Core i5    0  256     Intel
# 3            0    1  220.534624  Intel Core i7    0  512       AMD
# 4            0    1  226.983005  Intel Core i5    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sn.barplot(x=df['os'],y=df['Prices'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sn.distplot(df['Weight'])
# Out:
# C:\Users\ROSHNI\AppData\Local\Temp\ipykernel_11656\572135600.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sn.distplot(np.log(df['Prices']))
# Out:
# C:\Users\ROSHNI\AppData\Local\Temp\ipykernel_11656\2592709758.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(np.log(df['Prices']))
# <Axes: xlabel='Prices', ylabel='Density'>

# %%
df.drop(columns=['Product','laptop_ID'])
# Out:
#      Company            TypeName  Ram  Weight       Prices  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37  120759.6566            0    1
# 1      Apple           Ultrabook    8    1.34   81030.4516            0    0
# 2         HP            Notebook    8    1.86   51830.5000            0    0
# 3      Apple           Ultrabook   16    1.83  228725.7430            0    1
# 4      Apple           Ultrabook    8    1.37  162576.5040            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   57509.3200            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30  135119.8600            1    1
# 1300  Lenovo            Notebook    2    1.50   20642.0600            0    0
# 1301      HP            Notebook    6    2.19   68866.9600            0    0
# 1302    Asus            Notebook    4    2.20   33261.6600            0    0
#
#              PPI              Cpu_Brand   HDD  SSD Gpu_Brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other Intel Processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other Intel Processor   500    0     Intel
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1303 rows x 13 columns]

# %%
X = df.drop(columns=['Prices'])
y = np.log(df['Prices'])

# %%
X.shape
# Out:
# (1303, 14)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
len(X_train)
# Out:
# 1042

# %%
len(X_test)
# Out:
# 261

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   Product      1303 non-null   object
#  3   TypeName     1303 non-null   object
#  4   Ram          1303 non-null   int32
#  5   Weight       1303 non-null   float32
#  6   Prices       1303 non-null   float64
#  7   Touchscreen  1303 non-null   int64
#  8   IPS          1303 non-null   int64
#  9   PPI          1303 non-null   float64
#  10  Cpu_Brand    1303 non-null   object
#  11  HDD          1303 non-null   int32
#  12  SSD          1303 non-null   int32
#  13  Gpu_Brand    1303 non-null   object
#  14  os           1303 non-null   object
# dtypes: float32(1), float64(2), int32(3), int64(3), object(6)
# memory usage: 132.5+ KB

# %% [markdown]
# ### LINEAR REGRESSION

# %%
# Identify categorical and numerical columns
categorical_cols = X_train.select_dtypes(include=['object']).columns
numerical_cols = X_train.select_dtypes(include=['number']).columns

# Define the preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8396523802487903

# %% [markdown]
# ### Ridge Regulariazation

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ridge', Ridge(alpha=10))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8567060413096037

# %% [markdown]
# ### Lasso Regularization

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('lasso',Lasso(alpha=0.001))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8515738946010127

# %% [markdown]
# ### KNN

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('knn',KNeighborsRegressor(n_neighbors=5))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8391342187925214

# %% [markdown]
# ### Decision Tree

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('DTree',DecisionTreeRegressor(max_depth=13))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8188587599713067

# %% [markdown]
# ### SVM

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svc',SVR(kernel='rbf',C=10000,epsilon=0.1))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.9032482387329536

# %% [markdown]
# ### Random Forrest

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('RForrest',RandomForestRegressor(n_estimators=100,
                              random_state=17,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=16))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.8942739177590711

# %% [markdown]
# ### Gradient Boost

# %%
# Define the pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('gbr',GradientBoostingRegressor(n_estimators=500))
])

# Fit the pipeline
pipe.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipe.predict(X_test)
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# R2 score: 0.909337747277752

# %%
# importing the model
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df.head(20)
# Out:
#     laptop_ID Company            Product   TypeName  Ram  Weight       Prices  \
# 0           1   Apple        MacBook Pro  Ultrabook    8    1.37  120759.6566
# 1           2   Apple        Macbook Air  Ultrabook    8    1.34   81030.4516
# 2           3      HP             250 G6   Notebook    8    1.86   51830.5000
# 3           4   Apple        MacBook Pro  Ultrabook   16    1.83  228725.7430
# 4           5   Apple        MacBook Pro  Ultrabook    8    1.37  162576.5040
# 5           6    Acer           Aspire 3   Notebook    4    2.10   36056.0000
# 6           7   Apple        MacBook Pro  Ultrabook   16    2.04  192896.8958
# 7           8   Apple        Macbook Air  Ultrabook    8    1.34  104445.2180
# 8           9    Asus    ZenBook UX430UN  Ultrabook   16    1.30  134759.3000
# 9          10    Acer            Swift 3  Ultrabook    8    1.60   69407.8000
# 10         11      HP             250 G6   Notebook    4    1.86   35506.1460
# 11         12      HP             250 G6   Notebook    4    1.86   31097.3986
# 12         13   Apple        MacBook Pro  Ultrabook   16    1.83  219938.8958
# 13         14    Dell      Inspiron 3567   Notebook    4    2.20   44970.8460
# 14         15   Apple        MacBook 12"  Ultrabook    8    0.92  113792.7360
# 15         16   Apple        MacBook Pro  Ultrabook    8    1.37  136882.0970
# 16         17    Dell      Inspiron 3567   Notebook    8    2.20   67154.3000
# 17         18   Apple        MacBook Pro  Ultrabook   16    1.83  257620.1200
# 18         19  Lenovo  IdeaPad 320-15IKB   Notebook    8    2.20   44979.8600
# 19         20    Dell             XPS 13  Ultrabook    8    1.22   88247.0600
#
#     Touchscreen  IPS         PPI              Cpu_Brand   HDD  SSD Gpu_Brand  \
# 0             0    1  226.983005          Intel Core i5     0  128     Intel
# 1             0    0  127.677940          Intel Core i5     0    0     Intel
# 2             0    0  141.211998          Intel Core i5     0  256     Intel
# 3             0    1  220.534624          Intel Core i7     0  512       AMD
# 4             0    1  226.983005          Intel Core i5     0  256     Intel
# 5             0    0  100.454670          AMD Processor   500    0       AMD
# 6             0    1  220.534624          Intel Core i7     0    0     Intel
# 7             0    0  127.677940          Intel Core i5     0    0     Intel
# 8             0    0  157.350512          Intel Core i7     0  512    Nvidia
# 9             0    1  157.350512          Intel Core i5     0  256     Intel
# 10            0    0  100.454670          Intel Core i5   500    0     Intel
# 11            0    0  141.211998          Intel Core i3   500    0     Intel
# 12            0    1  220.534624          Intel Core i7     0  256       AMD
# 13            0    0  141.211998          Intel Core i3     0  256       AMD
# 14            0    1  226.415547  Other Intel Processor     0  256     Intel
# 15            0    1  226.983005          Intel Core i5     0  256     Intel
# 16            0    0  141.211998          Intel Core i7     0  256       AMD
# 17            0    1  220.534624          Intel Core i7     0  512       AMD
# 18            0    0  141.211998          Intel Core i3  1000    0    Nvidia
# 19            1    1  165.632118          Intel Core i5     0  128     Intel
#
#                     os
# 0                  Mac
# 1                  Mac
# 2   Others/No OS/Linux
# 3                  Mac
# 4                  Mac
# 5              Windows
# 6                  Mac
# 7                  Mac
# 8              Windows
# 9              Windows
# 10  Others/No OS/Linux
# 11  Others/No OS/Linux
# 12                 Mac
# 13             Windows
# 14                 Mac
# 15                 Mac
# 16             Windows
# 17                 Mac
# 18  Others/No OS/Linux
# 19             Windows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   Product      1303 non-null   object
#  3   TypeName     1303 non-null   object
#  4   Ram          1303 non-null   int32
#  5   Weight       1303 non-null   float32
#  6   Prices       1303 non-null   float64
#  7   Touchscreen  1303 non-null   int64
#  8   IPS          1303 non-null   int64
#  9   PPI          1303 non-null   float64
#  10  Cpu_Brand    1303 non-null   object
#  11  HDD          1303 non-null   int32
#  12  SSD          1303 non-null   int32
#  13  Gpu_Brand    1303 non-null   object
#  14  os           1303 non-null   object
# dtypes: float32(1), float64(2), int32(3), int64(3), object(6)
# memory usage: 132.5+ KB
